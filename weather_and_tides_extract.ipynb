# %%
from config import w_key
import requests
import json
import pandas as pd
# Out:
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
#
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
#
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
# Traceback (most recent call last):
#   File "/Users/tylerbrown/opt/anaconda3/envs/TestEnvironment/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 3343, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-1-07aba4894a12>", line 1, in <module>
#     from config import w_key
#   File "<frozen importlib._bootstrap>", line 971, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 951, in _find_and_load_unlocked
#   File "<frozen importlib._bootstrap>", line 894, in _find_spec
#   File "<frozen importlib._bootstrap_external>", line 1157, in find_spec
#   File "<frozen importlib._bootstrap_external>", line 1126, in _get_spec
# ERROR! Session/line number was not unique in  File "<frozen importlib._bootstrap_external>", line 1090, in _path_importer_cache
# PermissionError: [Errno 1] Operation not permitted
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/tylerbrown/opt/anaconda3/envs/TestEnvironment/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 2044, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'PermissionError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
#  Traceback (most recent call last):
#   File "/Users/tylerbrown/opt/anaconda3/envs/TestEnvironment/lib/python3.6/site-packages/IPython/core/ultratb.py", line 1169, in get_records
#     return _fixed_getinnerframes(etb, number_of_lines_of_context, tb_offset)
# database. History logging moved to new session 282
#   File "/Users/tylerbrown/opt/anaconda3/envs/TestEnvironment/lib/python3.6/site-packages/IPython/core/ultratb.py", line 316, in wrapped
#     return f(*args, **kwargs)
#   File "/Users/tylerbrown/opt/anaconda3/envs/TestEnvironment/lib/python3.6/site-packages/IPython/core/ultratb.py", line 350, in _fixed_getinnerframes
#     records = fix_frame_records_filenames(inspect.getinnerframes(etb, context))
#   File "/Users/tylerbrown/opt/anaconda3/envs/TestEnvironment/lib/python3.6/inspect.py", line 1490, in getinnerframes
#     frameinfo = (tb.tb_frame,) + getframeinfo(tb, context)
#   File "/Users/tylerbrown/opt/anaconda3/envs/TestEnvironment/lib/python3.6/inspect.py", line 1448, in getframeinfo
#     filename = getsourcefile(frame) or getfile(frame)
#   File "/Users/tylerbrown/opt/anaconda3/envs/TestEnvironment/lib/python3.6/inspect.py", line 696, in getsourcefile
#     if getattr(getmodule(object, filename), '__loader__', None) is not None:
#   File "/Users/tylerbrown/opt/anaconda3/envs/TestEnvironment/lib/python3.6/inspect.py", line 725, in getmodule
#     file = getabsfile(object, _filename)
#   File "/Users/tylerbrown/opt/anaconda3/envs/TestEnvironment/lib/python3.6/inspect.py", line 709, in getabsfile
#     return os.path.normcase(os.path.abspath(_filename))
#   File "/Users/tylerbrown/opt/anaconda3/envs/TestEnvironment/lib/python3.6/posixpath.py", line 383, in abspath
#     cwd = os.getcwd()
# PermissionError: [Errno 1] Operation not permitted
# Traceback (most recent call last):
#   File "/Users/tylerbrown/opt/anaconda3/envs/TestEnvironment/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 3343, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-1-07aba4894a12>", line 1, in <module>
#     from config import w_key
#   File "<frozen importlib._bootstrap>", line 971, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 951, in _find_and_load_unlocked
#   File "<frozen importlib._bootstrap>", line 894, in _find_spec
#   File "<frozen importlib._bootstrap_external>", line 1157, in find_spec
#   File "<frozen importlib._bootstrap_external>", line 1126, in _get_spec
#   File "<frozen importlib._bootstrap_external>", line 1090, in _path_importer_cache
# PermissionError: [Errno 1] Operation not permitted
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/tylerbrown/opt/anaconda3/envs/TestEnvironment/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 2044, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'PermissionError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/tylerbrown/opt/anaconda3/envs/TestEnvironment/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 3263, in run_ast_nodes
#     if (await self.run_code(code, result,  async_=asy)):
#   File "/Users/tylerbrown/opt/anaconda3/envs/TestEnvironment/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 3360, in run_code
#     self.showtraceback(running_compiled_code=True)
#   File "/Users/tylerbrown/opt/anaconda3/envs/TestEnvironment/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 2047, in showtraceback
#     value, tb, tb_offset=tb_offset)
#   File "/Users/tylerbrown/opt/anaconda3/envs/TestEnvironment/lib/python3.6/site-packages/IPython/core/ultratb.py", line 1436, in structured_traceback
#     self, etype, value, tb, tb_offset, number_of_lines_of_context)
#   File "/Users/tylerbrown/opt/anaconda3/envs/TestEnvironment/lib/python3.6/site-packages/IPython/core/ultratb.py", line 1336, in structured_traceback
#     self, etype, value, tb, tb_offset, number_of_lines_of_context
#   File "/Users/tylerbrown/opt/anaconda3/envs/TestEnvironment/lib/python3.6/site-packages/IPython/core/ultratb.py", line 1193, in structured_traceback
#     tb_offset)
#   File "/Users/tylerbrown/opt/anaconda3/envs/TestEnvironment/lib/python3.6/site-packages/IPython/core/ultratb.py", line 1150, in format_exception_as_a_whole
#     last_unique, recursion_repeat = find_recursion(orig_etype, evalue, records)
#   File "/Users/tylerbrown/opt/anaconda3/envs/TestEnvironment/lib/python3.6/site-packages/IPython/core/ultratb.py", line 451, in find_recursion
#     return len(records), 0
# TypeError: object of type 'NoneType' has no len()
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/tylerbrown/opt/anaconda3/envs/TestEnvironment/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 2044, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'TypeError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/tylerbrown/opt/anaconda3/envs/TestEnvironment/lib/python3.6/site-packages/IPython/core/ultratb.py", line 1169, in get_records
#     return _fixed_getinnerframes(etb, number_of_lines_of_context, tb_offset)
#   File "/Users/tylerbrown/opt/anaconda3/envs/TestEnvironment/lib/python3.6/site-packages/IPython/core/ultratb.py", line 316, in wrapped
#     return f(*args, **kwargs)
#   File "/Users/tylerbrown/opt/anaconda3/envs/TestEnvironment/lib/python3.6/site-packages/IPython/core/ultratb.py", line 350, in _fixed_getinnerframes
#     records = fix_frame_records_filenames(inspect.getinnerframes(etb, context))
#   File "/Users/tylerbrown/opt/anaconda3/envs/TestEnvironment/lib/python3.6/inspect.py", line 1490, in getinnerframes
#     frameinfo = (tb.tb_frame,) + getframeinfo(tb, context)
#   File "/Users/tylerbrown/opt/anaconda3/envs/TestEnvironment/lib/python3.6/inspect.py", line 1448, in getframeinfo
#     filename = getsourcefile(frame) or getfile(frame)
#   File "/Users/tylerbrown/opt/anaconda3/envs/TestEnvironment/lib/python3.6/inspect.py", line 696, in getsourcefile
#     if getattr(getmodule(object, filename), '__loader__', None) is not None:
#   File "/Users/tylerbrown/opt/anaconda3/envs/TestEnvironment/lib/python3.6/inspect.py", line 725, in getmodule
#     file = getabsfile(object, _filename)
#   File "/Users/tylerbrown/opt/anaconda3/envs/TestEnvironment/lib/python3.6/inspect.py", line 709, in getabsfile
#     return os.path.normcase(os.path.abspath(_filename))
#   File "/Users/tylerbrown/opt/anaconda3/envs/TestEnvironment/lib/python3.6/posixpath.py", line 383, in abspath
#     cwd = os.getcwd()
# PermissionError: [Errno 1] Operation not permitted
# Traceback (most recent call last):
#   File "/Users/tylerbrown/opt/anaconda3/envs/TestEnvironment/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 3343, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-1-07aba4894a12>", line 1, in <module>
#     from config import w_key
#   File "<frozen importlib._bootstrap>", line 971, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 951, in _find_and_load_unlocked
#   File "<frozen importlib._bootstrap>", line 894, in _find_spec
#   File "<frozen importlib._bootstrap_external>", line 1157, in find_spec
#   File "<frozen importlib._bootstrap_external>", line 1126, in _get_spec
#   File "<frozen importlib._bootstrap_external>", line 1090, in _path_importer_cache
# PermissionError: [Errno 1] Operation not permitted
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/tylerbrown/opt/anaconda3/envs/TestEnvironment/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 2044, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'PermissionError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/tylerbrown/opt/anaconda3/envs/TestEnvironment/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 3263, in run_ast_nodes
#     if (await self.run_code(code, result,  async_=asy)):
#   File "/Users/tylerbrown/opt/anaconda3/envs/TestEnvironment/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 3360, in run_code
#     self.showtraceback(running_compiled_code=True)
#   File "/Users/tylerbrown/opt/anaconda3/envs/TestEnvironment/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 2047, in showtraceback
#     value, tb, tb_offset=tb_offset)
#   File "/Users/tylerbrown/opt/anaconda3/envs/TestEnvironment/lib/python3.6/site-packages/IPython/core/ultratb.py", line 1436, in structured_traceback
#     self, etype, value, tb, tb_offset, number_of_lines_of_context)
#   File "/Users/tylerbrown/opt/anaconda3/envs/TestEnvironment/lib/python3.6/site-packages/IPython/core/ultratb.py", line 1336, in structured_traceback
#     self, etype, value, tb, tb_offset, number_of_lines_of_context
#   File "/Users/tylerbrown/opt/anaconda3/envs/TestEnvironment/lib/python3.6/site-packages/IPython/core/ultratb.py", line 1193, in structured_traceback
#     tb_offset)
#   File "/Users/tylerbrown/opt/anaconda3/envs/TestEnvironment/lib/python3.6/site-packages/IPython/core/ultratb.py", line 1150, in format_exception_as_a_whole
#     last_unique, recursion_repeat = find_recursion(orig_etype, evalue, records)
#   File "/Users/tylerbrown/opt/anaconda3/envs/TestEnvironment/lib/python3.6/site-packages/IPython/core/ultratb.py", line 451, in find_recursion
#     return len(records), 0
# TypeError: object of type 'NoneType' has no len()
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/tylerbrown/opt/anaconda3/envs/TestEnvironment/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 2044, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'TypeError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/tylerbrown/opt/anaconda3/envs/TestEnvironment/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 2895, in _run_cell
#     return runner(coro)
#   File "/Users/tylerbrown/opt/anaconda3/envs/TestEnvironment/lib/python3.6/site-packages/IPython/core/async_helpers.py", line 68, in _pseudo_sync_runner
#     coro.send(None)
#   File "/Users/tylerbrown/opt/anaconda3/envs/TestEnvironment/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 3072, in run_cell_async
#     interactivity=interactivity, compiler=compiler, result=result)
#   File "/Users/tylerbrown/opt/anaconda3/envs/TestEnvironment/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 3282, in run_ast_nodes
#     self.showtraceback()
#   File "/Users/tylerbrown/opt/anaconda3/envs/TestEnvironment/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 2047, in showtraceback
#     value, tb, tb_offset=tb_offset)
#   File "/Users/tylerbrown/opt/anaconda3/envs/TestEnvironment/lib/python3.6/site-packages/IPython/core/ultratb.py", line 1436, in structured_traceback
#     self, etype, value, tb, tb_offset, number_of_lines_of_context)
#   File "/Users/tylerbrown/opt/anaconda3/envs/TestEnvironment/lib/python3.6/site-packages/IPython/core/ultratb.py", line 1336, in structured_traceback
#     self, etype, value, tb, tb_offset, number_of_lines_of_context
#   File "/Users/tylerbrown/opt/anaconda3/envs/TestEnvironment/lib/python3.6/site-packages/IPython/core/ultratb.py", line 1211, in structured_traceback
#     chained_exceptions_tb_offset)
#   File "/Users/tylerbrown/opt/anaconda3/envs/TestEnvironment/lib/python3.6/site-packages/IPython/core/ultratb.py", line 1150, in format_exception_as_a_whole
#     last_unique, recursion_repeat = find_recursion(orig_etype, evalue, records)
#   File "/Users/tylerbrown/opt/anaconda3/envs/TestEnvironment/lib/python3.6/site-packages/IPython/core/ultratb.py", line 451, in find_recursion
#     return len(records), 0
# TypeError: object of type 'NoneType' has no len()
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/tylerbrown/opt/anaconda3/envs/TestEnvironment/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 2044, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'TypeError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/tylerbrown/opt/anaconda3/envs/TestEnvironment/lib/python3.6/site-packages/IPython/core/ultratb.py", line 1169, in get_records
#     return _fixed_getinnerframes(etb, number_of_lines_of_context, tb_offset)
#   File "/Users/tylerbrown/opt/anaconda3/envs/TestEnvironment/lib/python3.6/site-packages/IPython/core/ultratb.py", line 316, in wrapped
#     return f(*args, **kwargs)
#   File "/Users/tylerbrown/opt/anaconda3/envs/TestEnvironment/lib/python3.6/site-packages/IPython/core/ultratb.py", line 350, in _fixed_getinnerframes
#     records = fix_frame_records_filenames(inspect.getinnerframes(etb, context))
#   File "/Users/tylerbrown/opt/anaconda3/envs/TestEnvironment/lib/python3.6/inspect.py", line 1490, in getinnerframes
#     frameinfo = (tb.tb_frame,) + getframeinfo(tb, context)
#   File "/Users/tylerbrown/opt/anaconda3/envs/TestEnvironment/lib/python3.6/inspect.py", line 1448, in getframeinfo
#     filename = getsourcefile(frame) or getfile(frame)
#   File "/Users/tylerbrown/opt/anaconda3/envs/TestEnvironment/lib/python3.6/inspect.py", line 696, in getsourcefile
#     if getattr(getmodule(object, filename), '__loader__', None) is not None:
#   File "/Users/tylerbrown/opt/anaconda3/envs/TestEnvironment/lib/python3.6/inspect.py", line 725, in getmodule
#     file = getabsfile(object, _filename)
#   File "/Users/tylerbrown/opt/anaconda3/envs/TestEnvironment/lib/python3.6/inspect.py", line 709, in getabsfile
#     return os.path.normcase(os.path.abspath(_filename))
#   File "/Users/tylerbrown/opt/anaconda3/envs/TestEnvironment/lib/python3.6/posixpath.py", line 383, in abspath
#     cwd = os.getcwd()
# PermissionError: [Errno 1] Operation not permitted

# %%
path = "Resources/us_station_id.csv"
coord_csv = pd.read_csv(path)
coord_csv
# Out:
#       Station ID        Lat         Lng
# 0          25704  51.883583 -176.642481
# 1          26610  62.500000 -164.420000
# 2          45701  52.830000  173.320000
# 3          25502  56.899487 -154.247847
# 4          26515  66.551833 -152.622167
# ...          ...        ...         ...
# 3430       94053  42.064528 -104.152694
# 3431       24082  42.000000 -104.166700
# 3432       24083  42.066700 -104.966700
# 3433       24062  43.962889 -107.950528
# 3434       94173  44.550000 -110.416700
#
# [3435 rows x 3 columns]

# %%
path = "Resources/coops_active_current_stations.csv"
curr_csv = pd.read_csv(path)
curr_csv
# Out:
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
#
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
#
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
# Traceback (most recent call last):
#   File "/Users/tylerbrown/opt/anaconda3/envs/TestEnvironment/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 3343, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-1-ca52880a4a9c>", line 2, in <module>
#     curr_csv = pd.read_csv(path)
# NameError: name 'pd' is not defined
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/tylerbrown/opt/anaconda3/envs/TestEnvironment/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 2044, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'NameError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/tylerbrown/opt/anaconda3/envs/TestEnvironment/lib/python3.6/site-packages/IPython/core/ultratb.py", line 1169, in get_records
#     return _fixed_getinnerframes(etb, number_of_lines_of_context, tb_offset)
#   File "/Users/tylerbrown/opt/anaconda3/envs/TestEnvironment/lib/python3.6/site-packages/IPython/core/ultratb.py", line 316, in wrapped
#     return f(*args, **kwargs)
#   File "/Users/tylerbrown/opt/anaconda3/envs/TestEnvironment/lib/python3.6/site-packages/IPython/core/ultratb.py", line 350, in _fixed_getinnerframes
#     records = fix_frame_records_filenames(inspect.getinnerframes(etb, context))
#   File "/Users/tylerbrown/opt/anaconda3/envs/TestEnvironment/lib/python3.6/inspect.py", line 1490, in getinnerframes
#     frameinfo = (tb.tb_frame,) + getframeinfo(tb, context)
#   File "/Users/tylerbrown/opt/anaconda3/envs/TestEnvironment/lib/python3.6/inspect.py", line 1448, in getframeinfo
#     filename = getsourcefile(frame) or getfile(frame)
#   File "/Users/tylerbrown/opt/anaconda3/envs/TestEnvironment/lib/python3.6/inspect.py", line 696, in getsourcefile
#     if getattr(getmodule(object, filename), '__loader__', None) is not None:
#   File "/Users/tylerbrown/opt/anaconda3/envs/TestEnvironment/lib/python3.6/inspect.py", line 725, in getmodule
#     file = getabsfile(object, _filename)
#   File "/Users/tylerbrown/opt/anaconda3/envs/TestEnvironment/lib/python3.6/inspect.py", line 709, in getabsfile
#     return os.path.normcase(os.path.abspath(_filename))
#   File "/Users/tylerbrown/opt/anaconda3/envs/TestEnvironment/lib/python3.6/posixpath.py", line 383, in abspath
#     cwd = os.getcwd()
# PermissionError: [Errno 1] Operation not permitted
# Traceback (most recent call last):
#   File "/Users/tylerbrown/opt/anaconda3/envs/TestEnvironment/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 3343, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-1-ca52880a4a9c>", line 2, in <module>
#     curr_csv = pd.read_csv(path)
# NameError: name 'pd' is not defined
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/tylerbrown/opt/anaconda3/envs/TestEnvironment/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 2044, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'NameError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/tylerbrown/opt/anaconda3/envs/TestEnvironment/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 3263, in run_ast_nodes
#     if (await self.run_code(code, result,  async_=asy)):
#   File "/Users/tylerbrown/opt/anaconda3/envs/TestEnvironment/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 3360, in run_code
#     self.showtraceback(running_compiled_code=True)
#   File "/Users/tylerbrown/opt/anaconda3/envs/TestEnvironment/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 2047, in showtraceback
#     value, tb, tb_offset=tb_offset)
#   File "/Users/tylerbrown/opt/anaconda3/envs/TestEnvironment/lib/python3.6/site-packages/IPython/core/ultratb.py", line 1436, in structured_traceback
#     self, etype, value, tb, tb_offset, number_of_lines_of_context)
#   File "/Users/tylerbrown/opt/anaconda3/envs/TestEnvironment/lib/python3.6/site-packages/IPython/core/ultratb.py", line 1336, in structured_traceback
#     self, etype, value, tb, tb_offset, number_of_lines_of_context
#   File "/Users/tylerbrown/opt/anaconda3/envs/TestEnvironment/lib/python3.6/site-packages/IPython/core/ultratb.py", line 1193, in structured_traceback
#     tb_offset)
#   File "/Users/tylerbrown/opt/anaconda3/envs/TestEnvironment/lib/python3.6/site-packages/IPython/core/ultratb.py", line 1150, in format_exception_as_a_whole
#     last_unique, recursion_repeat = find_recursion(orig_etype, evalue, records)
#   File "/Users/tylerbrown/opt/anaconda3/envs/TestEnvironment/lib/python3.6/site-packages/IPython/core/ultratb.py", line 451, in find_recursion
#     return len(records), 0
# TypeError: object of type 'NoneType' has no len()
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/tylerbrown/opt/anaconda3/envs/TestEnvironment/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 2044, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'TypeError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/tylerbrown/opt/anaconda3/envs/TestEnvironment/lib/python3.6/site-packages/IPython/core/ultratb.py", line 1169, in get_records
#     return _fixed_getinnerframes(etb, number_of_lines_of_context, tb_offset)
#   File "/Users/tylerbrown/opt/anaconda3/envs/TestEnvironment/lib/python3.6/site-packages/IPython/core/ultratb.py", line 316, in wrapped
#     return f(*args, **kwargs)
#   File "/Users/tylerbrown/opt/anaconda3/envs/TestEnvironment/lib/python3.6/site-packages/IPython/core/ultratb.py", line 350, in _fixed_getinnerframes
#     records = fix_frame_records_filenames(inspect.getinnerframes(etb, context))
#   File "/Users/tylerbrown/opt/anaconda3/envs/TestEnvironment/lib/python3.6/inspect.py", line 1490, in getinnerframes
#     frameinfo = (tb.tb_frame,) + getframeinfo(tb, context)
#   File "/Users/tylerbrown/opt/anaconda3/envs/TestEnvironment/lib/python3.6/inspect.py", line 1448, in getframeinfo
#     filename = getsourcefile(frame) or getfile(frame)
#   File "/Users/tylerbrown/opt/anaconda3/envs/TestEnvironment/lib/python3.6/inspect.py", line 696, in getsourcefile
#     if getattr(getmodule(object, filename), '__loader__', None) is not None:
#   File "/Users/tylerbrown/opt/anaconda3/envs/TestEnvironment/lib/python3.6/inspect.py", line 725, in getmodule
#     file = getabsfile(object, _filename)
#   File "/Users/tylerbrown/opt/anaconda3/envs/TestEnvironment/lib/python3.6/inspect.py", line 709, in getabsfile
#     return os.path.normcase(os.path.abspath(_filename))
#   File "/Users/tylerbrown/opt/anaconda3/envs/TestEnvironment/lib/python3.6/posixpath.py", line 383, in abspath
#     cwd = os.getcwd()
# PermissionError: [Errno 1] Operation not permitted
# Traceback (most recent call last):
#   File "/Users/tylerbrown/opt/anaconda3/envs/TestEnvironment/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 3343, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-1-ca52880a4a9c>", line 2, in <module>
#     curr_csv = pd.read_csv(path)
# NameError: name 'pd' is not defined
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/tylerbrown/opt/anaconda3/envs/TestEnvironment/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 2044, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'NameError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/tylerbrown/opt/anaconda3/envs/TestEnvironment/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 3263, in run_ast_nodes
#     if (await self.run_code(code, result,  async_=asy)):
#   File "/Users/tylerbrown/opt/anaconda3/envs/TestEnvironment/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 3360, in run_code
#     self.showtraceback(running_compiled_code=True)
#   File "/Users/tylerbrown/opt/anaconda3/envs/TestEnvironment/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 2047, in showtraceback
#     value, tb, tb_offset=tb_offset)
#   File "/Users/tylerbrown/opt/anaconda3/envs/TestEnvironment/lib/python3.6/site-packages/IPython/core/ultratb.py", line 1436, in structured_traceback
#     self, etype, value, tb, tb_offset, number_of_lines_of_context)
#   File "/Users/tylerbrown/opt/anaconda3/envs/TestEnvironment/lib/python3.6/site-packages/IPython/core/ultratb.py", line 1336, in structured_traceback
#     self, etype, value, tb, tb_offset, number_of_lines_of_context
#   File "/Users/tylerbrown/opt/anaconda3/envs/TestEnvironment/lib/python3.6/site-packages/IPython/core/ultratb.py", line 1193, in structured_traceback
#     tb_offset)
#   File "/Users/tylerbrown/opt/anaconda3/envs/TestEnvironment/lib/python3.6/site-packages/IPython/core/ultratb.py", line 1150, in format_exception_as_a_whole
#     last_unique, recursion_repeat = find_recursion(orig_etype, evalue, records)
#   File "/Users/tylerbrown/opt/anaconda3/envs/TestEnvironment/lib/python3.6/site-packages/IPython/core/ultratb.py", line 451, in find_recursion
#     return len(records), 0
# TypeError: object of type 'NoneType' has no len()
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/tylerbrown/opt/anaconda3/envs/TestEnvironment/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 2044, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'TypeError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/tylerbrown/opt/anaconda3/envs/TestEnvironment/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 2895, in _run_cell
#     return runner(coro)
#   File "/Users/tylerbrown/opt/anaconda3/envs/TestEnvironment/lib/python3.6/site-packages/IPython/core/async_helpers.py", line 68, in _pseudo_sync_runner
#     coro.send(None)
#   File "/Users/tylerbrown/opt/anaconda3/envs/TestEnvironment/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 3072, in run_cell_async
#     interactivity=interactivity, compiler=compiler, result=result)
#   File "/Users/tylerbrown/opt/anaconda3/envs/TestEnvironment/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 3282, in run_ast_nodes
#     self.showtraceback()
#   File "/Users/tylerbrown/opt/anaconda3/envs/TestEnvironment/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 2047, in showtraceback
#     value, tb, tb_offset=tb_offset)
#   File "/Users/tylerbrown/opt/anaconda3/envs/TestEnvironment/lib/python3.6/site-packages/IPython/core/ultratb.py", line 1436, in structured_traceback
#     self, etype, value, tb, tb_offset, number_of_lines_of_context)
#   File "/Users/tylerbrown/opt/anaconda3/envs/TestEnvironment/lib/python3.6/site-packages/IPython/core/ultratb.py", line 1336, in structured_traceback
#     self, etype, value, tb, tb_offset, number_of_lines_of_context
#   File "/Users/tylerbrown/opt/anaconda3/envs/TestEnvironment/lib/python3.6/site-packages/IPython/core/ultratb.py", line 1211, in structured_traceback
#     chained_exceptions_tb_offset)
#   File "/Users/tylerbrown/opt/anaconda3/envs/TestEnvironment/lib/python3.6/site-packages/IPython/core/ultratb.py", line 1150, in format_exception_as_a_whole
#     last_unique, recursion_repeat = find_recursion(orig_etype, evalue, records)
#   File "/Users/tylerbrown/opt/anaconda3/envs/TestEnvironment/lib/python3.6/site-packages/IPython/core/ultratb.py", line 451, in find_recursion
#     return len(records), 0
# TypeError: object of type 'NoneType' has no len()
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/tylerbrown/opt/anaconda3/envs/TestEnvironment/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 2044, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'TypeError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/tylerbrown/opt/anaconda3/envs/TestEnvironment/lib/python3.6/site-packages/IPython/core/ultratb.py", line 1169, in get_records
#     return _fixed_getinnerframes(etb, number_of_lines_of_context, tb_offset)
#   File "/Users/tylerbrown/opt/anaconda3/envs/TestEnvironment/lib/python3.6/site-packages/IPython/core/ultratb.py", line 316, in wrapped
#     return f(*args, **kwargs)
#   File "/Users/tylerbrown/opt/anaconda3/envs/TestEnvironment/lib/python3.6/site-packages/IPython/core/ultratb.py", line 350, in _fixed_getinnerframes
#     records = fix_frame_records_filenames(inspect.getinnerframes(etb, context))
#   File "/Users/tylerbrown/opt/anaconda3/envs/TestEnvironment/lib/python3.6/inspect.py", line 1490, in getinnerframes
#     frameinfo = (tb.tb_frame,) + getframeinfo(tb, context)
#   File "/Users/tylerbrown/opt/anaconda3/envs/TestEnvironment/lib/python3.6/inspect.py", line 1448, in getframeinfo
#     filename = getsourcefile(frame) or getfile(frame)
#   File "/Users/tylerbrown/opt/anaconda3/envs/TestEnvironment/lib/python3.6/inspect.py", line 696, in getsourcefile
#     if getattr(getmodule(object, filename), '__loader__', None) is not None:
#   File "/Users/tylerbrown/opt/anaconda3/envs/TestEnvironment/lib/python3.6/inspect.py", line 725, in getmodule
#     file = getabsfile(object, _filename)
#   File "/Users/tylerbrown/opt/anaconda3/envs/TestEnvironment/lib/python3.6/inspect.py", line 709, in getabsfile
#     return os.path.normcase(os.path.abspath(_filename))
#   File "/Users/tylerbrown/opt/anaconda3/envs/TestEnvironment/lib/python3.6/posixpath.py", line 383, in abspath
#     cwd = os.getcwd()
# PermissionError: [Errno 1] Operation not permitted

# %%
#TO TEST A DIFFERENT TYPE OF CURRENT API CALL.... Ignore this one

url = f"https://api.tidesandcurrents.noaa.gov/mdapi/prod/webapi/stations/9414290/nearby.json?radius=3"
#url = f"https://api.tidesandcurrents.noaa.gov/mdapi/prod/webapi/lat/51.883583/lng/-176.642481/nearby.json?radius=3"
response = requests.get(url).json()
print(json.dumps(response, indent=4, sort_keys=True))
# Out:
# {
#     "count": null,
#     "self": "https://api.tidesandcurrents.noaa.gov/mdapi/prod/webapi/stations/45701/nearby.json",
#     "stations": [],
#     "units": null
# }

# %%
#TO TEST STATION IDS
url = f"https://api.tidesandcurrents.noaa.gov/api/prod/datagetter?date=today&station=ca0101&product=currents_predictions&units=metric&time_zone=gmt&application=ports_screen&format=json"
response = requests.get(url).json()
print(json.dumps(response, indent=4, sort_keys=True))
#print(response["current_predictions"]["cp"][0]["Velocity_Major"])
# Out:
# {
#     "current_predictions": {
#         "cp": [
#             {
#                 "Bin": "20",
#                 "Depth": "4",
#                 "Time": "2020-12-02 00:00",
#                 "Velocity_Major": 164.1,
#                 "meanEbbDir": 217,
#                 "meanFloodDir": 41
#             },
#             {
#                 "Bin": "20",
#                 "Depth": "4",
#                 "Time": "2020-12-02 00:06",
#                 "Velocity_Major": 164.3,
#                 "meanEbbDir": 217,
#                 "meanFloodDir": 41
#             },
#             {
#                 "Bin": "20",
#                 "Depth": "4",
#                 "Time": "2020-12-02 00:12",
#                 "Velocity_Major": 164.4,
#                 "meanEbbDir": 217,
#                 "meanFloodDir": 41
#             },
#             {
#                 "Bin": "20",
#                 "Depth": "4",
#                 "Time": "2020-12-02 00:18",
#                 "Velocity_Major": 164.3,
#                 "meanEbbDir": 217,
#                 "meanFloodDir": 41
#             },
#             {
#                 "Bin": "20",
#                 "Depth": "4",
#                 "Time": "2020-12-02 00:24",
#                 "Velocity_Major": 164.1,
#                 "meanEbbDir": 217,
#                 "meanFloodDir": 41
#             },
#             {
#                 "Bin": "20",
#                 "Depth": "4",
#                 "Time": "2020-12-02 00:30",
#                 "Velocity_Major": 163.7,
#                 "meanEbbDir": 217,
#                 "meanFloodDir": 41
#             },
#             {
#                 "Bin": "20",
#                 "Depth": "4",
#                 "Time": "2020-12-02 00:36",
#                 "Velocity_Major": 163.3,
#                 "meanEbbDir": 217,
#                 "meanFloodDir": 41
#             },
#             {
#                 "Bin": "20",
#                 "Depth": "4",
#                 "Time": "2020-12-02 00:42",
#                 "Velocity_Major": 162.8,
#                 "meanEbbDir": 217,
#                 "meanFloodDir": 41
#             },
#             {
#                 "Bin": "20",
#                 "Depth": "4",
#                 "Time": "2020-12-02 00:48",
#                 "Velocity_Major": 162.2,
#                 "meanEbbDir": 217,
#                 "meanFloodDir": 41
#             },
#             {
#                 "Bin": "20",
#                 "Depth": "4",
#                 "Time": "2020-12-02 00:54",
#                 "Velocity_Major": 161.6,
#                 "meanEbbDir": 217,
#                 "meanFloodDir": 41
#             },
#             {
#                 "Bin": "20",
#                 "Depth": "4",
#                 "Time": "2020-12-02 01:00",
#                 "Velocity_Major": 160.9,
#                 "meanEbbDir": 217,
#                 "meanFloodDir": 41
#             },
#             {
#                 "Bin": "20",
#                 "Depth": "4",
#                 "Time": "2020-12-02 01:06",
#                 "Velocity_Major": 160,
#                 "meanEbbDir": 217,
#                 "meanFloodDir": 41
#             },
#             {
#                 "Bin": "20",
#                 "Depth": "4",
#                 "Time": "2020-12-02 01:12",
#                 "Velocity_Major": 159.1,
#                 "meanEbbDir": 217,
#                 "meanFloodDir": 41
#             },
#             {
#                 "Bin": "20",
#                 "Depth": "4",
#                 "Time": "2020-12-02 01:18",
#                 "Velocity_Major": 157.9,
#                 "meanEbbDir": 217,
#                 "meanFloodDir": 41
#             },
#             {
#                 "Bin": "20",
#                 "Depth": "4",
#                 "Time": "2020-12-02 01:24",
#                 "Velocity_Major": 156.6,
#                 "meanEbbDir": 217,
#                 "meanFloodDir": 41
#             },
#             {
#                 "Bin": "20",
#                 "Depth": "4",
#                 "Time": "2020-12-02 01:30",
#                 "Velocity_Major": 155.1,
#                 "meanEbbDir": 217,
#                 "meanFloodDir": 41
#             },
#             {
#                 "Bin": "20",
#                 "Depth": "4",
#                 "Time": "2020-12-02 01:36",
#                 "Velocity_Major": 153.3,
#                 "meanEbbDir": 217,
#                 "meanFloodDir": 41
#             },
#             {
#                 "Bin": "20",
#                 "Depth": "4",
#                 "Time": "2020-12-02 01:42",
#                 "Velocity_Major": 151.2,
#                 "meanEbbDir": 217,
#                 "meanFloodDir": 41
#             },
#             {
#                 "Bin": "20",
#                 "Depth": "4",
#                 "Time": "2020-12-02 01:48",
#                 "Velocity_Major": 148.8,
#                 "meanEbbDir": 217,
#                 "meanFloodDir": 41
#             },
#             {
#                 "Bin": "20",
#                 "Depth": "4",
#                 "Time": "2020-12-02 01:54",
#                 "Velocity_Major": 145.9,
#                 "meanEbbDir": 217,
#                 "meanFloodDir": 41
#             },
#             {
#                 "Bin": "20",
#                 "Depth": "4",
#                 "Time": "2020-12-02 02:00",
#                 "Velocity_Major": 142.6,
#                 "meanEbbDir": 217,
#                 "meanFloodDir": 41
#             },
#             {
#                 "Bin": "20",
#                 "Depth": "4",
#                 "Time": "2020-12-02 02:06",
#                 "Velocity_Major": 138.7,
#                 "meanEbbDir": 217,
#                 "meanFloodDir": 41
#             },
#             {
#                 "Bin": "20",
#                 "Depth": "4",
#                 "Time": "2020-12-02 02:12",
#                 "Velocity_Major": 134.3,
#                 "meanEbbDir": 217,
#                 "meanFloodDir": 41
#             },
#             {
#                 "Bin": "20",
#                 "Depth": "4",
#                 "Time": "2020-12-02 02:18",
#                 "Velocity_Major": 129.3,
#                 "meanEbbDir": 217,
#                 "meanFloodDir": 41
#             },
#             {
#                 "Bin": "20",
#                 "Depth": "4",
#                 "Time": "2020-12-02 02:24",
#                 "Velocity_Major": 123.6,
#                 "meanEbbDir": 217,
#                 "meanFloodDir": 41
#             },
#             {
#                 "Bin": "20",
#                 "Depth": "4",
#                 "Time": "2020-12-02 02:30",
#                 "Velocity_Major": 117.1,
#                 "meanEbbDir": 217,
#                 "meanFloodDir": 41
#             },
#             {
#                 "Bin": "20",
#                 "Depth": "4",
#                 "Time": "2020-12-02 02:36",
#                 "Velocity_Major": 109.9,
#                 "meanEbbDir": 217,
#                 "meanFloodDir": 41
#             },
#             {
#                 "Bin": "20",
#                 "Depth": "4",
#                 "Time": "2020-12-02 02:42",
#                 "Velocity_Major": 102,
#                 "meanEbbDir": 217,
#                 "meanFloodDir": 41
#             },
#             {
#                 "Bin": "20",
#                 "Depth": "4",
#                 "Time": "2020-12-02 02:48",
#                 "Velocity_Major": 93.2,
#                 "meanEbbDir": 217,
#                 "meanFloodDir": 41
#             },
#             {
#                 "Bin": "20",
#                 "Depth": "4",
#                 "Time": "2020-12-02 02:54",
#                 "Velocity_Major": 83.6,
#                 "meanEbbDir": 217,
#                 "meanFloodDir": 41
#             },
#             {
#                 "Bin": "20",
#                 "Depth": "4",
#                 "Time": "2020-12-02 03:00",
#                 "Velocity_Major": 73.3,
#                 "meanEbbDir": 217,
#                 "meanFloodDir": 41
#             },
#             {
#                 "Bin": "20",
#                 "Depth": "4",
#                 "Time": "2020-12-02 03:06",
#                 "Velocity_Major": 62.1,
#                 "meanEbbDir": 217,
#                 "meanFloodDir": 41
#             },
#             {
#                 "Bin": "20",
#                 "Depth": "4",
#                 "Time": "2020-12-02 03:12",
#                 "Velocity_Major": 50.2,
#                 "meanEbbDir": 217,
#                 "meanFloodDir": 41
#             },
#             {
#                 "Bin": "20",
#                 "Depth": "4",
#                 "Time": "2020-12-02 03:18",
#                 "Velocity_Major": 37.7,
#                 "meanEbbDir": 217,
#                 "meanFloodDir": 41
#             },
#             {
#                 "Bin": "20",
#                 "Depth": "4",
#                 "Time": "2020-12-02 03:24",
#                 "Velocity_Major": 24.4,
#                 "meanEbbDir": 217,
#                 "meanFloodDir": 41
#             },
#             {
#                 "Bin": "20",
#                 "Depth": "4",
#                 "Time": "2020-12-02 03:30",
#                 "Velocity_Major": 10.7,
#                 "meanEbbDir": 217,
#                 "meanFloodDir": 41
#             },
#             {
#                 "Bin": "20",
#                 "Depth": "4",
#                 "Time": "2020-12-02 03:36",
#                 "Velocity_Major": -3.6,
#                 "meanEbbDir": 217,
#                 "meanFloodDir": 41
#             },
#             {
#                 "Bin": "20",
#                 "Depth": "4",
#                 "Time": "2020-12-02 03:42",
#                 "Velocity_Major": -18.2,
#                 "meanEbbDir": 217,
#                 "meanFloodDir": 41
#             },
#             {
#                 "Bin": "20",
#                 "Depth": "4",
#                 "Time": "2020-12-02 03:48",
#                 "Velocity_Major": -33,
#                 "meanEbbDir": 217,
#                 "meanFloodDir": 41
#             },
#             {
#                 "Bin": "20",
#                 "Depth": "4",
#                 "Time": "2020-12-02 03:54",
#                 "Velocity_Major": -48,
#                 "meanEbbDir": 217,
#                 "meanFloodDir": 41
#             },
#             {
#                 "Bin": "20",
#                 "Depth": "4",
#                 "Time": "2020-12-02 04:00",
#                 "Velocity_Major": -63.1,
#                 "meanEbbDir": 217,
#                 "meanFloodDir": 41
#             },
#             {
#                 "Bin": "20",
#                 "Depth": "4",
#                 "Time": "2020-12-02 04:06",
#                 "Velocity_Major": -78,
#                 "meanEbbDir": 217,
#                 "meanFloodDir": 41
#             },
#             {
#                 "Bin": "20",
#                 "Depth": "4",
#                 "Time": "2020-12-02 04:12",
#                 "Velocity_Major": -92.7,
#                 "meanEbbDir": 217,
#                 "meanFloodDir": 41
#             },
#             {
#                 "Bin": "20",
#                 "Depth": "4",
#                 "Time": "2020-12-02 04:18",
#                 "Velocity_Major": -107.1,
#                 "meanEbbDir": 217,
#                 "meanFloodDir": 41
#             },
#             {
#                 "Bin": "20",
#                 "Depth": "4",
#                 "Time": "2020-12-02 04:24",
#                 "Velocity_Major": -120.9,
#                 "meanEbbDir": 217,
#                 "meanFloodDir": 41
#             },
#             {
#                 "Bin": "20",
#                 "Depth": "4",
#                 "Time": "2020-12-02 04:30",
#                 "Velocity_Major": -134.2,
#                 "meanEbbDir": 217,
#                 "meanFloodDir": 41
#             },
#             {
#                 "Bin": "20",
#                 "Depth": "4",
#                 "Time": "2020-12-02 04:36",
#                 "Velocity_Major": -146.7,
#                 "meanEbbDir": 217,
#                 "meanFloodDir": 41
#             },
#             {
#                 "Bin": "20",
#                 "Depth": "4",
#                 "Time": "2020-12-02 04:42",
#                 "Velocity_Major": -158.5,
#                 "meanEbbDir": 217,
#                 "meanFloodDir": 41
#             },
#             {
#                 "Bin": "20",
#                 "Depth": "4",
#                 "Time": "2020-12-02 04:48",
#                 "Velocity_Major": -169.1,
#                 "meanEbbDir": 217,
#                 "meanFloodDir": 41
#             },
#             {
#                 "Bin": "20",
#                 "Depth": "4",
#                 "Time": "2020-12-02 04:54",
#                 "Velocity_Major": -179,
#                 "meanEbbDir": 217,
#                 "meanFloodDir": 41
#             },
#             {
#                 "Bin": "20",
#                 "Depth": "4",
#                 "Time": "2020-12-02 05:00",
#                 "Velocity_Major": -188,
#                 "meanEbbDir": 217,
#                 "meanFloodDir": 41
#             },
#             {
#                 "Bin": "20",
#                 "Depth": "4",
#                 "Time": "2020-12-02 05:06",
#                 "Velocity_Major": -195.9,
#                 "meanEbbDir": 217,
#                 "meanFloodDir": 41
#             },
#             {
#                 "Bin": "20",
#                 "Depth": "4",
#                 "Time": "2020-12-02 05:12",
#                 "Velocity_Major": -202.7,
#                 "meanEbbDir": 217,
#                 "meanFloodDir": 41
#             },
#             {
#                 "Bin": "20",
#                 "Depth": "4",
#                 "Time": "2020-12-02 05:18",
#                 "Velocity_Major": -208.5,
#                 "meanEbbDir": 217,
#                 "meanFloodDir": 41
#             },
#             {
#                 "Bin": "20",
#                 "Depth": "4",
#                 "Time": "2020-12-02 05:24",
#                 "Velocity_Major": -213.3,
#                 "meanEbbDir": 217,
#                 "meanFloodDir": 41
#             },
#             {
#                 "Bin": "20",
#                 "Depth": "4",
#                 "Time": "2020-12-02 05:30",
#                 "Velocity_Major": -217,
#                 "meanEbbDir": 217,
#                 "meanFloodDir": 41
#             },
#             {
#                 "Bin": "20",
#                 "Depth": "4",
#                 "Time": "2020-12-02 05:36",
#                 "Velocity_Major": -219.8,
#                 "meanEbbDir": 217,
#                 "meanFloodDir": 41
#             },
#             {
#                 "Bin": "20",
#                 "Depth": "4",
#                 "Time": "2020-12-02 05:42",
#                 "Velocity_Major": -221.6,
#                 "meanEbbDir": 217,
#                 "meanFloodDir": 41
#             },
#             {
#                 "Bin": "20",
#                 "Depth": "4",
#                 "Time": "2020-12-02 05:48",
#                 "Velocity_Major": -222.6,
#                 "meanEbbDir": 217,
#                 "meanFloodDir": 41
#             },
#             {
#                 "Bin": "20",
#                 "Depth": "4",
#                 "Time": "2020-12-02 05:54",
#                 "Velocity_Major": -222.8,
#                 "meanEbbDir": 217,
#                 "meanFloodDir": 41
#             },
#             {
#                 "Bin": "20",
#                 "Depth": "4",
#                 "Time": "2020-12-02 06:00",
#                 "Velocity_Major": -222.3,
#                 "meanEbbDir": 217,
#                 "meanFloodDir": 41
#             },
#             {
#                 "Bin": "20",
#                 "Depth": "4",
#                 "Time": "2020-12-02 06:06",
#                 "Velocity_Major": -221.3,
#                 "meanEbbDir": 217,
#                 "meanFloodDir": 41
#             },
#             {
#                 "Bin": "20",
#                 "Depth": "4",
#                 "Time": "2020-12-02 06:12",
#                 "Velocity_Major": -219.7,
#                 "meanEbbDir": 217,
#                 "meanFloodDir": 41
#             },
#             {
#                 "Bin": "20",
#                 "Depth": "4",
#                 "Time": "2020-12-02 06:18",
#                 "Velocity_Major": -217.6,
#                 "meanEbbDir": 217,
#                 "meanFloodDir": 41
#             },
#             {
#                 "Bin": "20",
#                 "Depth": "4",
#                 "Time": "2020-12-02 06:24",
#                 "Velocity_Major": -215.2,
#                 "meanEbbDir": 217,
#                 "meanFloodDir": 41
#             },
#             {
#                 "Bin": "20",
#                 "Depth": "4",
#                 "Time": "2020-12-02 06:30",
#                 "Velocity_Major": -212.5,
#                 "meanEbbDir": 217,
#                 "meanFloodDir": 41
#             },
#             {
#                 "Bin": "20",
#                 "Depth": "4",
#                 "Time": "2020-12-02 06:36",
#                 "Velocity_Major": -209.6,
#                 "meanEbbDir": 217,
#                 "meanFloodDir": 41
#             },
#             {
#                 "Bin": "20",
#                 "Depth": "4",
#                 "Time": "2020-12-02 06:42",
#                 "Velocity_Major": -206.5,
#                 "meanEbbDir": 217,
#                 "meanFloodDir": 41
#             },
#             {
#                 "Bin": "20",
#                 "Depth": "4",
#                 "Time": "2020-12-02 06:48",
#                 "Velocity_Major": -203.2,
#                 "meanEbbDir": 217,
#                 "meanFloodDir": 41
#             },
#             {
#                 "Bin": "20",
#                 "Depth": "4",
#                 "Time": "2020-12-02 06:54",
#                 "Velocity_Major": -199.9,
#                 "meanEbbDir": 217,
#                 "meanFloodDir": 41
#             },
#             {
#                 "Bin": "20",
#                 "Depth": "4",
#                 "Time": "2020-12-02 07:00",
#                 "Velocity_Major": -196.4,
#                 "meanEbbDir": 217,
#                 "meanFloodDir": 41
#             },
#             {
#                 "Bin": "20",
#                 "Depth": "4",
#                 "Time": "2020-12-02 07:06",
#                 "Velocity_Major": -193,
#                 "meanEbbDir": 217,
#                 "meanFloodDir": 41
#             },
#             {
#                 "Bin": "20",
#                 "Depth": "4",
#                 "Time": "2020-12-02 07:12",
#                 "Velocity_Major": -189.4,
#                 "meanEbbDir": 217,
#                 "meanFloodDir": 41
#             },
#             {
#                 "Bin": "20",
#                 "Depth": "4",
#                 "Time": "2020-12-02 07:18",
#                 "Velocity_Major": -185.6,
#                 "meanEbbDir": 217,
#                 "meanFloodDir": 41
#             },
#             {
#                 "Bin": "20",
#                 "Depth": "4",
#                 "Time": "2020-12-02 07:24",
#                 "Velocity_Major": -181.8,
#                 "meanEbbDir": 217,
#                 "meanFloodDir": 41
#             },
#             {
#                 "Bin": "20",
#                 "Depth": "4",
#                 "Time": "2020-12-02 07:30",
#                 "Velocity_Major": -177.8,
#                 "meanEbbDir": 217,
#                 "meanFloodDir": 41
#             },
#             {
#                 "Bin": "20",
#                 "Depth": "4",
#                 "Time": "2020-12-02 07:36",
#                 "Velocity_Major": -173.7,
#                 "meanEbbDir": 217,
#                 "meanFloodDir": 41
#             },
#             {
#                 "Bin": "20",
#                 "Depth": "4",
#                 "Time": "2020-12-02 07:42",
#                 "Velocity_Major": -169.2,
#                 "meanEbbDir": 217,
#                 "meanFloodDir": 41
#             },
#             {
#                 "Bin": "20",
#                 "Depth": "4",
#                 "Time": "2020-12-02 07:48",
#                 "Velocity_Major": -164.4,
#                 "meanEbbDir": 217,
#                 "meanFloodDir": 41
#             },
#             {
#                 "Bin": "20",
#                 "Depth": "4",
#                 "Time": "2020-12-02 07:54",
#                 "Velocity_Major": -159.3,
#                 "meanEbbDir": 217,
#                 "meanFloodDir": 41
#             },
#             {
#                 "Bin": "20",
#                 "Depth": "4",
#                 "Time": "2020-12-02 08:00",
#                 "Velocity_Major": -153.8,
#                 "meanEbbDir": 217,
#                 "meanFloodDir": 41
#             },
#             {
#                 "Bin": "20",
#                 "Depth": "4",
#                 "Time": "2020-12-02 08:06",
#                 "Velocity_Major": -147.9,
#                 "meanEbbDir": 217,
#                 "meanFloodDir": 41
#             },
#             {
#                 "Bin": "20",
#                 "Depth": "4",
#                 "Time": "2020-12-02 08:12",
#                 "Velocity_Major": -141.4,
#                 "meanEbbDir": 217,
#                 "meanFloodDir": 41
#             },
#             {
#                 "Bin": "20",
#                 "Depth": "4",
#                 "Time": "2020-12-02 08:18",
#                 "Velocity_Major": -134.4,
#                 "meanEbbDir": 217,
#                 "meanFloodDir": 41
#             },
#             {
#                 "Bin": "20",
#                 "Depth": "4",
#                 "Time": "2020-12-02 08:24",
#                 "Velocity_Major": -126.9,
#                 "meanEbbDir": 217,
#                 "meanFloodDir": 41
#             },
#             {
#                 "Bin": "20",
#                 "Depth": "4",
#                 "Time": "2020-12-02 08:30",
#                 "Velocity_Major": -118.8,
#                 "meanEbbDir": 217,
#                 "meanFloodDir": 41
#             },
#             {
#                 "Bin": "20",
#                 "Depth": "4",
#                 "Time": "2020-12-02 08:36",
#                 "Velocity_Major": -110.2,
#                 "meanEbbDir": 217,
#                 "meanFloodDir": 41
#             },
#             {
#                 "Bin": "20",
#                 "Depth": "4",
#                 "Time": "2020-12-02 08:42",
#                 "Velocity_Major": -100.9,
#                 "meanEbbDir": 217,
#                 "meanFloodDir": 41
#             },
#             {
#                 "Bin": "20",
#                 "Depth": "4",
#                 "Time": "2020-12-02 08:48",
#                 "Velocity_Major": -91.1,
#                 "meanEbbDir": 217,
#                 "meanFloodDir": 41
#             },
#             {
#                 "Bin": "20",
#                 "Depth": "4",
#                 "Time": "2020-12-02 08:54",
#                 "Velocity_Major": -80.8,
#                 "meanEbbDir": 217,
#                 "meanFloodDir": 41
#             },
#             {
#                 "Bin": "20",
#                 "Depth": "4",
#                 "Time": "2020-12-02 09:00",
#                 "Velocity_Major": -70.1,
#                 "meanEbbDir": 217,
#                 "meanFloodDir": 41
#             },
#             {
#                 "Bin": "20",
#                 "Depth": "4",
#                 "Time": "2020-12-02 09:06",
#                 "Velocity_Major": -58.9,
#                 "meanEbbDir": 217,
#                 "meanFloodDir": 41
#             },
#             {
#                 "Bin": "20",
#                 "Depth": "4",
#                 "Time": "2020-12-02 09:12",
#                 "Velocity_Major": -47.3,
#                 "meanEbbDir": 217,
#                 "meanFloodDir": 41
#             },
#             {
#                 "Bin": "20",
#                 "Depth": "4",
#                 "Time": "2020-12-02 09:18",
#                 "Velocity_Major": -35.8,
#                 "meanEbbDir": 217,
#                 "meanFloodDir": 41
#             },
#             {
#                 "Bin": "20",
#                 "Depth": "4",
#                 "Time": "2020-12-02 09:24",
#                 "Velocity_Major": -23.7,
#                 "meanEbbDir": 217,
#                 "meanFloodDir": 41
#             },
#             {
#                 "Bin": "20",
#                 "Depth": "4",
#                 "Time": "2020-12-02 09:30",
#                 "Velocity_Major": -11.5,
#                 "meanEbbDir": 217,
#                 "meanFloodDir": 41
#             },
#             {
#                 "Bin": "20",
#                 "Depth": "4",
#                 "Time": "2020-12-02 09:36",
#                 "Velocity_Major": 0.8,
#                 "meanEbbDir": 217,
#                 "meanFloodDir": 41
#             },
#             {
#                 "Bin": "20",
#                 "Depth": "4",
#                 "Time": "2020-12-02 09:42",
#                 "Velocity_Major": 13.1,
#                 "meanEbbDir": 217,
#                 "meanFloodDir": 41
#             },
#             {
#                 "Bin": "20",
#                 "Depth": "4",
#                 "Time": "2020-12-02 09:48",
#                 "Velocity_Major": 25.3,
#                 "meanEbbDir": 217,
#                 "meanFloodDir": 41
#             },
#             {
#                 "Bin": "20",
#                 "Depth": "4",
#                 "Time": "2020-12-02 09:54",
#                 "Velocity_Major": 37.2,
#                 "meanEbbDir": 217,
#                 "meanFloodDir": 41
#             },
#             {
#                 "Bin": "20",
#                 "Depth": "4",
#                 "Time": "2020-12-02 10:00",
#                 "Velocity_Major": 48.9,
#                 "meanEbbDir": 217,
#                 "meanFloodDir": 41
#             },
#             {
#                 "Bin": "20",
#                 "Depth": "4",
#                 "Time": "2020-12-02 10:06",
#                 "Velocity_Major": 60.3,
#                 "meanEbbDir": 217,
#                 "meanFloodDir": 41
#             },
#             {
#                 "Bin": "20",
#                 "Depth": "4",
#                 "Time": "2020-12-02 10:12",
#                 "Velocity_Major": 71.3,
#                 "meanEbbDir": 217,
#                 "meanFloodDir": 41
#             },
#             {
#                 "Bin": "20",
#                 "Depth": "4",
#                 "Time": "2020-12-02 10:18",
#                 "Velocity_Major": 81.9,
#                 "meanEbbDir": 217,
#                 "meanFloodDir": 41
#             },
#             {
#                 "Bin": "20",
#                 "Depth": "4",
#                 "Time": "2020-12-02 10:24",
#                 "Velocity_Major": 92,
#                 "meanEbbDir": 217,
#                 "meanFloodDir": 41
#             },
#             {
#                 "Bin": "20",
#                 "Depth": "4",
#                 "Time": "2020-12-02 10:30",
#                 "Velocity_Major": 101.4,
#                 "meanEbbDir": 217,
#                 "meanFloodDir": 41
#             },
#             {
#                 "Bin": "20",
#                 "Depth": "4",
#                 "Time": "2020-12-02 10:36",
#                 "Velocity_Major": 110.3,
#                 "meanEbbDir": 217,
#                 "meanFloodDir": 41
#             },
#             {
#                 "Bin": "20",
#                 "Depth": "4",
#                 "Time": "2020-12-02 10:42",
#                 "Velocity_Major": 118.5,
#                 "meanEbbDir": 217,
#                 "meanFloodDir": 41
#             },
#             {
#                 "Bin": "20",
#                 "Depth": "4",
#                 "Time": "2020-12-02 10:48",
#                 "Velocity_Major": 126,
#                 "meanEbbDir": 217,
#                 "meanFloodDir": 41
#             },
#             {
#                 "Bin": "20",
#                 "Depth": "4",
#                 "Time": "2020-12-02 10:54",
#                 "Velocity_Major": 133,
#                 "meanEbbDir": 217,
#                 "meanFloodDir": 41
#             },
#             {
#                 "Bin": "20",
#                 "Depth": "4",
#                 "Time": "2020-12-02 11:00",
#                 "Velocity_Major": 139.2,
#                 "meanEbbDir": 217,
#                 "meanFloodDir": 41
#             },
#             {
#                 "Bin": "20",
#                 "Depth": "4",
#                 "Time": "2020-12-02 11:06",
#                 "Velocity_Major": 144.8,
#                 "meanEbbDir": 217,
#                 "meanFloodDir": 41
#             },
#             {
#                 "Bin": "20",
#                 "Depth": "4",
#                 "Time": "2020-12-02 11:12",
#                 "Velocity_Major": 149.7,
#                 "meanEbbDir": 217,
#                 "meanFloodDir": 41
#             },
#             {
#                 "Bin": "20",
#                 "Depth": "4",
#                 "Time": "2020-12-02 11:18",
#                 "Velocity_Major": 153.9,
#                 "meanEbbDir": 217,
#                 "meanFloodDir": 41
#             },
#             {
#                 "Bin": "20",
#                 "Depth": "4",
#                 "Time": "2020-12-02 11:24",
#                 "Velocity_Major": 157.5,
#                 "meanEbbDir": 217,
#                 "meanFloodDir": 41
#             },
#             {
#                 "Bin": "20",
#                 "Depth": "4",
#                 "Time": "2020-12-02 11:30",
#                 "Velocity_Major": 160.6,
#                 "meanEbbDir": 217,
#                 "meanFloodDir": 41
#             },
#             {
#                 "Bin": "20",
#                 "Depth": "4",
#                 "Time": "2020-12-02 11:36",
#                 "Velocity_Major": 162.9,
#                 "meanEbbDir": 217,
#                 "meanFloodDir": 41
#             },
#             {
#                 "Bin": "20",
#                 "Depth": "4",
#                 "Time": "2020-12-02 11:42",
#                 "Velocity_Major": 164.8,
#                 "meanEbbDir": 217,
#                 "meanFloodDir": 41
#             },
#             {
#                 "Bin": "20",
#                 "Depth": "4",
#                 "Time": "2020-12-02 11:48",
#                 "Velocity_Major": 166.1,
#                 "meanEbbDir": 217,
#                 "meanFloodDir": 41
#             },
#             {
#                 "Bin": "20",
#                 "Depth": "4",
#                 "Time": "2020-12-02 11:54",
#                 "Velocity_Major": 166.9,
#                 "meanEbbDir": 217,
#                 "meanFloodDir": 41
#             },
#             {
#                 "Bin": "20",
#                 "Depth": "4",
#                 "Time": "2020-12-02 12:00",
#                 "Velocity_Major": 167.2,
#                 "meanEbbDir": 217,
#                 "meanFloodDir": 41
#             },
#             {
#                 "Bin": "20",
#                 "Depth": "4",
#                 "Time": "2020-12-02 12:06",
#                 "Velocity_Major": 167.2,
#                 "meanEbbDir": 217,
#                 "meanFloodDir": 41
#             },
#             {
#                 "Bin": "20",
#                 "Depth": "4",
#                 "Time": "2020-12-02 12:12",
#                 "Velocity_Major": 166.7,
#                 "meanEbbDir": 217,
#                 "meanFloodDir": 41
#             },
#             {
#                 "Bin": "20",
#                 "Depth": "4",
#                 "Time": "2020-12-02 12:18",
#                 "Velocity_Major": 165.8,
#                 "meanEbbDir": 217,
#                 "meanFloodDir": 41
#             },
#             {
#                 "Bin": "20",
#                 "Depth": "4",
#                 "Time": "2020-12-02 12:24",
#                 "Velocity_Major": 164.7,
#                 "meanEbbDir": 217,
#                 "meanFloodDir": 41
#             },
#             {
#                 "Bin": "20",
#                 "Depth": "4",
#                 "Time": "2020-12-02 12:30",
#                 "Velocity_Major": 163.1,
#                 "meanEbbDir": 217,
#                 "meanFloodDir": 41
#             },
#             {
#                 "Bin": "20",
#                 "Depth": "4",
#                 "Time": "2020-12-02 12:36",
#                 "Velocity_Major": 161.3,
#                 "meanEbbDir": 217,
#                 "meanFloodDir": 41
#             },
#             {
#                 "Bin": "20",
#                 "Depth": "4",
#                 "Time": "2020-12-02 12:42",
#                 "Velocity_Major": 159.3,
#                 "meanEbbDir": 217,
#                 "meanFloodDir": 41
#             },
#             {
#                 "Bin": "20",
#                 "Depth": "4",
#                 "Time": "2020-12-02 12:48",
#                 "Velocity_Major": 157,
#                 "meanEbbDir": 217,
#                 "meanFloodDir": 41
#             },
#             {
#                 "Bin": "20",
#                 "Depth": "4",
#                 "Time": "2020-12-02 12:54",
#                 "Velocity_Major": 154.6,
#                 "meanEbbDir": 217,
#                 "meanFloodDir": 41
#             },
#             {
#                 "Bin": "20",
#                 "Depth": "4",
#                 "Time": "2020-12-02 13:00",
#                 "Velocity_Major": 151.9,
#                 "meanEbbDir": 217,
#                 "meanFloodDir": 41
#             },
#             {
#                 "Bin": "20",
#                 "Depth": "4",
#                 "Time": "2020-12-02 13:06",
#                 "Velocity_Major": 149.2,
#                 "meanEbbDir": 217,
#                 "meanFloodDir": 41
#             },
#             {
#                 "Bin": "20",
#                 "Depth": "4",
#                 "Time": "2020-12-02 13:12",
#                 "Velocity_Major": 146.3,
#                 "meanEbbDir": 217,
#                 "meanFloodDir": 41
#             },
#             {
#                 "Bin": "20",
#                 "Depth": "4",
#                 "Time": "2020-12-02 13:18",
#                 "Velocity_Major": 143.1,
#                 "meanEbbDir": 217,
#                 "meanFloodDir": 41
#             },
#             {
#                 "Bin": "20",
#                 "Depth": "4",
#                 "Time": "2020-12-02 13:24",
#                 "Velocity_Major": 139.9,
#                 "meanEbbDir": 217,
#                 "meanFloodDir": 41
#             },
#             {
#                 "Bin": "20",
#                 "Depth": "4",
#                 "Time": "2020-12-02 13:30",
#                 "Velocity_Major": 136.5,
#                 "meanEbbDir": 217,
#                 "meanFloodDir": 41
#             },
#             {
#                 "Bin": "20",
#                 "Depth": "4",
#                 "Time": "2020-12-02 13:36",
#                 "Velocity_Major": 133.1,
#                 "meanEbbDir": 217,
#                 "meanFloodDir": 41
#             },
#             {
#                 "Bin": "20",
#                 "Depth": "4",
#                 "Time": "2020-12-02 13:42",
#                 "Velocity_Major": 129.5,
#                 "meanEbbDir": 217,
#                 "meanFloodDir": 41
#             },
#             {
#                 "Bin": "20",
#                 "Depth": "4",
#                 "Time": "2020-12-02 13:48",
#                 "Velocity_Major": 125.7,
#                 "meanEbbDir": 217,
#                 "meanFloodDir": 41
#             },
#             {
#                 "Bin": "20",
#                 "Depth": "4",
#                 "Time": "2020-12-02 13:54",
#                 "Velocity_Major": 121.7,
#                 "meanEbbDir": 217,
#                 "meanFloodDir": 41
#             },
#             {
#                 "Bin": "20",
#                 "Depth": "4",
#                 "Time": "2020-12-02 14:00",
#                 "Velocity_Major": 117.5,
#                 "meanEbbDir": 217,
#                 "meanFloodDir": 41
#             },
#             {
#                 "Bin": "20",
#                 "Depth": "4",
#                 "Time": "2020-12-02 14:06",
#                 "Velocity_Major": 113,
#                 "meanEbbDir": 217,
#                 "meanFloodDir": 41
#             },
#             {
#                 "Bin": "20",
#                 "Depth": "4",
#                 "Time": "2020-12-02 14:12",
#                 "Velocity_Major": 108.2,
#                 "meanEbbDir": 217,
#                 "meanFloodDir": 41
#             },
#             {
#                 "Bin": "20",
#                 "Depth": "4",
#                 "Time": "2020-12-02 14:18",
#                 "Velocity_Major": 103.1,
#                 "meanEbbDir": 217,
#                 "meanFloodDir": 41
#             },
#             {
#                 "Bin": "20",
#                 "Depth": "4",
#                 "Time": "2020-12-02 14:24",
#                 "Velocity_Major": 97.6,
#                 "meanEbbDir": 217,
#                 "meanFloodDir": 41
#             },
#             {
#                 "Bin": "20",
#                 "Depth": "4",
#                 "Time": "2020-12-02 14:30",
#                 "Velocity_Major": 91.7,
#                 "meanEbbDir": 217,
#                 "meanFloodDir": 41
#             },
#             {
#                 "Bin": "20",
#                 "Depth": "4",
#                 "Time": "2020-12-02 14:36",
#                 "Velocity_Major": 85.4,
#                 "meanEbbDir": 217,
#                 "meanFloodDir": 41
#             },
#             {
#                 "Bin": "20",
#                 "Depth": "4",
#                 "Time": "2020-12-02 14:42",
#                 "Velocity_Major": 78.6,
#                 "meanEbbDir": 217,
#                 "meanFloodDir": 41
#             },
#             {
#                 "Bin": "20",
#                 "Depth": "4",
#                 "Time": "2020-12-02 14:48",
#                 "Velocity_Major": 71.1,
#                 "meanEbbDir": 217,
#                 "meanFloodDir": 41
#             },
#             {
#                 "Bin": "20",
#                 "Depth": "4",
#                 "Time": "2020-12-02 14:54",
#                 "Velocity_Major": 63.2,
#                 "meanEbbDir": 217,
#                 "meanFloodDir": 41
#             },
#             {
#                 "Bin": "20",
#                 "Depth": "4",
#                 "Time": "2020-12-02 15:00",
#                 "Velocity_Major": 54.7,
#                 "meanEbbDir": 217,
#                 "meanFloodDir": 41
#             },
#             {
#                 "Bin": "20",
#                 "Depth": "4",
#                 "Time": "2020-12-02 15:06",
#                 "Velocity_Major": 45.5,
#                 "meanEbbDir": 217,
#                 "meanFloodDir": 41
#             },
#             {
#                 "Bin": "20",
#                 "Depth": "4",
#                 "Time": "2020-12-02 15:12",
#                 "Velocity_Major": 35.7,
#                 "meanEbbDir": 217,
#                 "meanFloodDir": 41
#             },
#             {
#                 "Bin": "20",
#                 "Depth": "4",
#                 "Time": "2020-12-02 15:18",
#                 "Velocity_Major": 25.3,
#                 "meanEbbDir": 217,
#                 "meanFloodDir": 41
#             },
#             {
#                 "Bin": "20",
#                 "Depth": "4",
#                 "Time": "2020-12-02 15:24",
#                 "Velocity_Major": 14.3,
#                 "meanEbbDir": 217,
#                 "meanFloodDir": 41
#             },
#             {
#                 "Bin": "20",
#                 "Depth": "4",
#                 "Time": "2020-12-02 15:30",
#                 "Velocity_Major": 2.6,
#                 "meanEbbDir": 217,
#                 "meanFloodDir": 41
#             },
#             {
#                 "Bin": "20",
#                 "Depth": "4",
#                 "Time": "2020-12-02 15:36",
#                 "Velocity_Major": -9.6,
#                 "meanEbbDir": 217,
#                 "meanFloodDir": 41
#             },
#             {
#                 "Bin": "20",
#                 "Depth": "4",
#                 "Time": "2020-12-02 15:42",
#                 "Velocity_Major": -22.4,
#                 "meanEbbDir": 217,
#                 "meanFloodDir": 41
#             },
#             {
#                 "Bin": "20",
#                 "Depth": "4",
#                 "Time": "2020-12-02 15:48",
#                 "Velocity_Major": -35.5,
#                 "meanEbbDir": 217,
#                 "meanFloodDir": 41
#             },
#             {
#                 "Bin": "20",
#                 "Depth": "4",
#                 "Time": "2020-12-02 15:54",
#                 "Velocity_Major": -49.2,
#                 "meanEbbDir": 217,
#                 "meanFloodDir": 41
#             },
#             {
#                 "Bin": "20",
#                 "Depth": "4",
#                 "Time": "2020-12-02 16:00",
#                 "Velocity_Major": -63.1,
#                 "meanEbbDir": 217,
#                 "meanFloodDir": 41
#             },
#             {
#                 "Bin": "20",
#                 "Depth": "4",
#                 "Time": "2020-12-02 16:06",
#                 "Velocity_Major": -77.3,
#                 "meanEbbDir": 217,
#                 "meanFloodDir": 41
#             },
#             {
#                 "Bin": "20",
#                 "Depth": "4",
#                 "Time": "2020-12-02 16:12",
#                 "Velocity_Major": -91.6,
#                 "meanEbbDir": 217,
#                 "meanFloodDir": 41
#             },
#             {
#                 "Bin": "20",
#                 "Depth": "4",
#                 "Time": "2020-12-02 16:18",
#                 "Velocity_Major": -105.9,
#                 "meanEbbDir": 217,
#                 "meanFloodDir": 41
#             },
#             {
#                 "Bin": "20",
#                 "Depth": "4",
#                 "Time": "2020-12-02 16:24",
#                 "Velocity_Major": -120.1,
#                 "meanEbbDir": 217,
#                 "meanFloodDir": 41
#             },
#             {
#                 "Bin": "20",
#                 "Depth": "4",
#                 "Time": "2020-12-02 16:30",
#                 "Velocity_Major": -134,
#                 "meanEbbDir": 217,
#                 "meanFloodDir": 41
#             },
#             {
#                 "Bin": "20",
#                 "Depth": "4",
#                 "Time": "2020-12-02 16:36",
#                 "Velocity_Major": -147.6,
#                 "meanEbbDir": 217,
#                 "meanFloodDir": 41
#             },
#             {
#                 "Bin": "20",
#                 "Depth": "4",
#                 "Time": "2020-12-02 16:42",
#                 "Velocity_Major": -160.7,
#                 "meanEbbDir": 217,
#                 "meanFloodDir": 41
#             },
#             {
#                 "Bin": "20",
#                 "Depth": "4",
#                 "Time": "2020-12-02 16:48",
#                 "Velocity_Major": -173.3,
#                 "meanEbbDir": 217,
#                 "meanFloodDir": 41
#             },
#             {
#                 "Bin": "20",
#                 "Depth": "4",
#                 "Time": "2020-12-02 16:54",
#                 "Velocity_Major": -185.2,
#                 "meanEbbDir": 217,
#                 "meanFloodDir": 41
#             },
#             {
#                 "Bin": "20",
#                 "Depth": "4",
#                 "Time": "2020-12-02 17:00",
#                 "Velocity_Major": -196.3,
#                 "meanEbbDir": 217,
#                 "meanFloodDir": 41
#             },
#             {
#                 "Bin": "20",
#                 "Depth": "4",
#                 "Time": "2020-12-02 17:06",
#                 "Velocity_Major": -206.5,
#                 "meanEbbDir": 217,
#                 "meanFloodDir": 41
#             },
#             {
#                 "Bin": "20",
#                 "Depth": "4",
#                 "Time": "2020-12-02 17:12",
#                 "Velocity_Major": -215.7,
#                 "meanEbbDir": 217,
#                 "meanFloodDir": 41
#             },
#             {
#                 "Bin": "20",
#                 "Depth": "4",
#                 "Time": "2020-12-02 17:18",
#                 "Velocity_Major": -224,
#                 "meanEbbDir": 217,
#                 "meanFloodDir": 41
#             },
#             {
#                 "Bin": "20",
#                 "Depth": "4",
#                 "Time": "2020-12-02 17:24",
#                 "Velocity_Major": -231.2,
#                 "meanEbbDir": 217,
#                 "meanFloodDir": 41
#             },
#             {
#                 "Bin": "20",
#                 "Depth": "4",
#                 "Time": "2020-12-02 17:30",
#                 "Velocity_Major": -237.2,
#                 "meanEbbDir": 217,
#                 "meanFloodDir": 41
#             },
#             {
#                 "Bin": "20",
#                 "Depth": "4",
#                 "Time": "2020-12-02 17:36",
#                 "Velocity_Major": -242.1,
#                 "meanEbbDir": 217,
#                 "meanFloodDir": 41
#             },
#             {
#                 "Bin": "20",
#                 "Depth": "4",
#                 "Time": "2020-12-02 17:42",
#                 "Velocity_Major": -246,
#                 "meanEbbDir": 217,
#                 "meanFloodDir": 41
#             },
#             {
#                 "Bin": "20",
#                 "Depth": "4",
#                 "Time": "2020-12-02 17:48",
#                 "Velocity_Major": -248.7,
#                 "meanEbbDir": 217,
#                 "meanFloodDir": 41
#             },
#             {
#                 "Bin": "20",
#                 "Depth": "4",
#                 "Time": "2020-12-02 17:54",
#                 "Velocity_Major": -250.3,
#                 "meanEbbDir": 217,
#                 "meanFloodDir": 41
#             },
#             {
#                 "Bin": "20",
#                 "Depth": "4",
#                 "Time": "2020-12-02 18:00",
#                 "Velocity_Major": -250.9,
#                 "meanEbbDir": 217,
#                 "meanFloodDir": 41
#             },
#             {
#                 "Bin": "20",
#                 "Depth": "4",
#                 "Time": "2020-12-02 18:06",
#                 "Velocity_Major": -250.5,
#                 "meanEbbDir": 217,
#                 "meanFloodDir": 41
#             },
#             {
#                 "Bin": "20",
#                 "Depth": "4",
#                 "Time": "2020-12-02 18:12",
#                 "Velocity_Major": -249.3,
#                 "meanEbbDir": 217,
#                 "meanFloodDir": 41
#             },
#             {
#                 "Bin": "20",
#                 "Depth": "4",
#                 "Time": "2020-12-02 18:18",
#                 "Velocity_Major": -247.3,
#                 "meanEbbDir": 217,
#                 "meanFloodDir": 41
#             },
#             {
#                 "Bin": "20",
#                 "Depth": "4",
#                 "Time": "2020-12-02 18:24",
#                 "Velocity_Major": -244.6,
#                 "meanEbbDir": 217,
#                 "meanFloodDir": 41
#             },
#             {
#                 "Bin": "20",
#                 "Depth": "4",
#                 "Time": "2020-12-02 18:30",
#                 "Velocity_Major": -241.3,
#                 "meanEbbDir": 217,
#                 "meanFloodDir": 41
#             },
#             {
#                 "Bin": "20",
#                 "Depth": "4",
#                 "Time": "2020-12-02 18:36",
#                 "Velocity_Major": -237.4,
#                 "meanEbbDir": 217,
#                 "meanFloodDir": 41
#             },
#             {
#                 "Bin": "20",
#                 "Depth": "4",
#                 "Time": "2020-12-02 18:42",
#                 "Velocity_Major": -233.1,
#                 "meanEbbDir": 217,
#                 "meanFloodDir": 41
#             },
#             {
#                 "Bin": "20",
#                 "Depth": "4",
#                 "Time": "2020-12-02 18:48",
#                 "Velocity_Major": -228.4,
#                 "meanEbbDir": 217,
#                 "meanFloodDir": 41
#             },
#             {
#                 "Bin": "20",
#                 "Depth": "4",
#                 "Time": "2020-12-02 18:54",
#                 "Velocity_Major": -223.4,
#                 "meanEbbDir": 217,
#                 "meanFloodDir": 41
#             },
#             {
#                 "Bin": "20",
#                 "Depth": "4",
#                 "Time": "2020-12-02 19:00",
#                 "Velocity_Major": -218.3,
#                 "meanEbbDir": 217,
#                 "meanFloodDir": 41
#             },
#             {
#                 "Bin": "20",
#                 "Depth": "4",
#                 "Time": "2020-12-02 19:06",
#                 "Velocity_Major": -213,
#                 "meanEbbDir": 217,
#                 "meanFloodDir": 41
#             },
#             {
#                 "Bin": "20",
#                 "Depth": "4",
#                 "Time": "2020-12-02 19:12",
#                 "Velocity_Major": -207.6,
#                 "meanEbbDir": 217,
#                 "meanFloodDir": 41
#             },
#             {
#                 "Bin": "20",
#                 "Depth": "4",
#                 "Time": "2020-12-02 19:18",
#                 "Velocity_Major": -202.2,
#                 "meanEbbDir": 217,
#                 "meanFloodDir": 41
#             },
#             {
#                 "Bin": "20",
#                 "Depth": "4",
#                 "Time": "2020-12-02 19:24",
#                 "Velocity_Major": -196.8,
#                 "meanEbbDir": 217,
#                 "meanFloodDir": 41
#             },
#             {
#                 "Bin": "20",
#                 "Depth": "4",
#                 "Time": "2020-12-02 19:30",
#                 "Velocity_Major": -191.4,
#                 "meanEbbDir": 217,
#                 "meanFloodDir": 41
#             },
#             {
#                 "Bin": "20",
#                 "Depth": "4",
#                 "Time": "2020-12-02 19:36",
#                 "Velocity_Major": -186,
#                 "meanEbbDir": 217,
#                 "meanFloodDir": 41
#             },
#             {
#                 "Bin": "20",
#                 "Depth": "4",
#                 "Time": "2020-12-02 19:42",
#                 "Velocity_Major": -180.6,
#                 "meanEbbDir": 217,
#                 "meanFloodDir": 41
#             },
#             {
#                 "Bin": "20",
#                 "Depth": "4",
#                 "Time": "2020-12-02 19:48",
#                 "Velocity_Major": -175.3,
#                 "meanEbbDir": 217,
#                 "meanFloodDir": 41
#             },
#             {
#                 "Bin": "20",
#                 "Depth": "4",
#                 "Time": "2020-12-02 19:54",
#                 "Velocity_Major": -169.8,
#                 "meanEbbDir": 217,
#                 "meanFloodDir": 41
#             },
#             {
#                 "Bin": "20",
#                 "Depth": "4",
#                 "Time": "2020-12-02 20:00",
#                 "Velocity_Major": -164.3,
#                 "meanEbbDir": 217,
#                 "meanFloodDir": 41
#             },
#             {
#                 "Bin": "20",
#                 "Depth": "4",
#                 "Time": "2020-12-02 20:06",
#                 "Velocity_Major": -158.7,
#                 "meanEbbDir": 217,
#                 "meanFloodDir": 41
#             },
#             {
#                 "Bin": "20",
#                 "Depth": "4",
#                 "Time": "2020-12-02 20:12",
#                 "Velocity_Major": -152.9,
#                 "meanEbbDir": 217,
#                 "meanFloodDir": 41
#             },
#             {
#                 "Bin": "20",
#                 "Depth": "4",
#                 "Time": "2020-12-02 20:18",
#                 "Velocity_Major": -146.9,
#                 "meanEbbDir": 217,
#                 "meanFloodDir": 41
#             },
#             {
#                 "Bin": "20",
#                 "Depth": "4",
#                 "Time": "2020-12-02 20:24",
#                 "Velocity_Major": -140.7,
#                 "meanEbbDir": 217,
#                 "meanFloodDir": 41
#             },
#             {
#                 "Bin": "20",
#                 "Depth": "4",
#                 "Time": "2020-12-02 20:30",
#                 "Velocity_Major": -134.1,
#                 "meanEbbDir": 217,
#                 "meanFloodDir": 41
#             },
#             {
#                 "Bin": "20",
#                 "Depth": "4",
#                 "Time": "2020-12-02 20:36",
#                 "Velocity_Major": -127.3,
#                 "meanEbbDir": 217,
#                 "meanFloodDir": 41
#             },
#             {
#                 "Bin": "20",
#                 "Depth": "4",
#                 "Time": "2020-12-02 20:42",
#                 "Velocity_Major": -120,
#                 "meanEbbDir": 217,
#                 "meanFloodDir": 41
#             },
#             {
#                 "Bin": "20",
#                 "Depth": "4",
#                 "Time": "2020-12-02 20:48",
#                 "Velocity_Major": -112.3,
#                 "meanEbbDir": 217,
#                 "meanFloodDir": 41
#             },
#             {
#                 "Bin": "20",
#                 "Depth": "4",
#                 "Time": "2020-12-02 20:54",
#                 "Velocity_Major": -104.2,
#                 "meanEbbDir": 217,
#                 "meanFloodDir": 41
#             },
#             {
#                 "Bin": "20",
#                 "Depth": "4",
#                 "Time": "2020-12-02 21:00",
#                 "Velocity_Major": -95.8,
#                 "meanEbbDir": 217,
#                 "meanFloodDir": 41
#             },
#             {
#                 "Bin": "20",
#                 "Depth": "4",
#                 "Time": "2020-12-02 21:06",
#                 "Velocity_Major": -86.8,
#                 "meanEbbDir": 217,
#                 "meanFloodDir": 41
#             },
#             {
#                 "Bin": "20",
#                 "Depth": "4",
#                 "Time": "2020-12-02 21:12",
#                 "Velocity_Major": -77.4,
#                 "meanEbbDir": 217,
#                 "meanFloodDir": 41
#             },
#             {
#                 "Bin": "20",
#                 "Depth": "4",
#                 "Time": "2020-12-02 21:18",
#                 "Velocity_Major": -67.6,
#                 "meanEbbDir": 217,
#                 "meanFloodDir": 41
#             },
#             {
#                 "Bin": "20",
#                 "Depth": "4",
#                 "Time": "2020-12-02 21:24",
#                 "Velocity_Major": -57.5,
#                 "meanEbbDir": 217,
#                 "meanFloodDir": 41
#             },
#             {
#                 "Bin": "20",
#                 "Depth": "4",
#                 "Time": "2020-12-02 21:30",
#                 "Velocity_Major": -46.9,
#                 "meanEbbDir": 217,
#                 "meanFloodDir": 41
#             },
#             {
#                 "Bin": "20",
#                 "Depth": "4",
#                 "Time": "2020-12-02 21:36",
#                 "Velocity_Major": -36.1,
#                 "meanEbbDir": 217,
#                 "meanFloodDir": 41
#             },
#             {
#                 "Bin": "20",
#                 "Depth": "4",
#                 "Time": "2020-12-02 21:42",
#                 "Velocity_Major": -25,
#                 "meanEbbDir": 217,
#                 "meanFloodDir": 41
#             },
#             {
#                 "Bin": "20",
#                 "Depth": "4",
#                 "Time": "2020-12-02 21:48",
#                 "Velocity_Major": -13.8,
#                 "meanEbbDir": 217,
#                 "meanFloodDir": 41
#             },
#             {
#                 "Bin": "20",
#                 "Depth": "4",
#                 "Time": "2020-12-02 21:54",
#                 "Velocity_Major": -2.4,
#                 "meanEbbDir": 217,
#                 "meanFloodDir": 41
#             },
#             {
#                 "Bin": "20",
#                 "Depth": "4",
#                 "Time": "2020-12-02 22:00",
#                 "Velocity_Major": 8.9,
#                 "meanEbbDir": 217,
#                 "meanFloodDir": 41
#             },
#             {
#                 "Bin": "20",
#                 "Depth": "4",
#                 "Time": "2020-12-02 22:06",
#                 "Velocity_Major": 20.3,
#                 "meanEbbDir": 217,
#                 "meanFloodDir": 41
#             },
#             {
#                 "Bin": "20",
#                 "Depth": "4",
#                 "Time": "2020-12-02 22:12",
#                 "Velocity_Major": 31.6,
#                 "meanEbbDir": 217,
#                 "meanFloodDir": 41
#             },
#             {
#                 "Bin": "20",
#                 "Depth": "4",
#                 "Time": "2020-12-02 22:18",
#                 "Velocity_Major": 42.8,
#                 "meanEbbDir": 217,
#                 "meanFloodDir": 41
#             },
#             {
#                 "Bin": "20",
#                 "Depth": "4",
#                 "Time": "2020-12-02 22:24",
#                 "Velocity_Major": 53.7,
#                 "meanEbbDir": 217,
#                 "meanFloodDir": 41
#             },
#             {
#                 "Bin": "20",
#                 "Depth": "4",
#                 "Time": "2020-12-02 22:30",
#                 "Velocity_Major": 64.2,
#                 "meanEbbDir": 217,
#                 "meanFloodDir": 41
#             },
#             {
#                 "Bin": "20",
#                 "Depth": "4",
#                 "Time": "2020-12-02 22:36",
#                 "Velocity_Major": 74.2,
#                 "meanEbbDir": 217,
#                 "meanFloodDir": 41
#             },
#             {
#                 "Bin": "20",
#                 "Depth": "4",
#                 "Time": "2020-12-02 22:42",
#                 "Velocity_Major": 84.1,
#                 "meanEbbDir": 217,
#                 "meanFloodDir": 41
#             },
#             {
#                 "Bin": "20",
#                 "Depth": "4",
#                 "Time": "2020-12-02 22:48",
#                 "Velocity_Major": 93.5,
#                 "meanEbbDir": 217,
#                 "meanFloodDir": 41
#             },
#             {
#                 "Bin": "20",
#                 "Depth": "4",
#                 "Time": "2020-12-02 22:54",
#                 "Velocity_Major": 102.4,
#                 "meanEbbDir": 217,
#                 "meanFloodDir": 41
#             },
#             {
#                 "Bin": "20",
#                 "Depth": "4",
#                 "Time": "2020-12-02 23:00",
#                 "Velocity_Major": 110.9,
#                 "meanEbbDir": 217,
#                 "meanFloodDir": 41
#             },
#             {
#                 "Bin": "20",
#                 "Depth": "4",
#                 "Time": "2020-12-02 23:06",
#                 "Velocity_Major": 118.8,
#                 "meanEbbDir": 217,
#                 "meanFloodDir": 41
#             },
#             {
#                 "Bin": "20",
#                 "Depth": "4",
#                 "Time": "2020-12-02 23:12",
#                 "Velocity_Major": 126.1,
#                 "meanEbbDir": 217,
#                 "meanFloodDir": 41
#             },
#             {
#                 "Bin": "20",
#                 "Depth": "4",
#                 "Time": "2020-12-02 23:18",
#                 "Velocity_Major": 132.8,
#                 "meanEbbDir": 217,
#                 "meanFloodDir": 41
#             },
#             {
#                 "Bin": "20",
#                 "Depth": "4",
#                 "Time": "2020-12-02 23:24",
#                 "Velocity_Major": 139,
#                 "meanEbbDir": 217,
#                 "meanFloodDir": 41
#             },
#             {
#                 "Bin": "20",
#                 "Depth": "4",
#                 "Time": "2020-12-02 23:30",
#                 "Velocity_Major": 144.6,
#                 "meanEbbDir": 217,
#                 "meanFloodDir": 41
#             },
#             {
#                 "Bin": "20",
#                 "Depth": "4",
#                 "Time": "2020-12-02 23:36",
#                 "Velocity_Major": 149.6,
#                 "meanEbbDir": 217,
#                 "meanFloodDir": 41
#             },
#             {
#                 "Bin": "20",
#                 "Depth": "4",
#                 "Time": "2020-12-02 23:42",
#                 "Velocity_Major": 154.1,
#                 "meanEbbDir": 217,
#                 "meanFloodDir": 41
#             },
#             {
#                 "Bin": "20",
#                 "Depth": "4",
#                 "Time": "2020-12-02 23:48",
#                 "Velocity_Major": 158,
#                 "meanEbbDir": 217,
#                 "meanFloodDir": 41
#             },
#             {
#                 "Bin": "20",
#                 "Depth": "4",
#                 "Time": "2020-12-02 23:54",
#                 "Velocity_Major": 161.3,
#                 "meanEbbDir": 217,
#                 "meanFloodDir": 41
#             }
#         ],
#         "units": "meters, cm/s"
#     }
# }

# %%
#Open weather query
units = "standard"
#lats = coord_csv["Lng"]
#lons = coord_csv["Lat"]

lats = ["51.883583"]
lons = ["-176.642481"]

#Outputs    
temps = []


for (lat, lon) in zip(lats, lons):
    w_url= f"http://api.openweathermap.org/data/2.5/weather?lat={lat}&lon={lon}&units={units}&appid={w_key}"
    w_query= requests.get(w_url).json()
    temp_get = w_query['main']['temp']
    temps.append(temp_get)

# %%
#Tide query
date = "today"
product = "currents_predictions"


t_stations = curr_csv["Station ID"].to_list()
datum = "MTL"
unit = "metric"
time = "lst"
format_j = "json"
app = "app"

#Outputs
velo = []
ebb = []
flood = []
s_result = []


for t_station in t_stations:
    try:
        t_url = f"https://api.tidesandcurrents.noaa.gov/api/prod/datagetter?date={date}&station={t_station}&product={product}&units={unit}&time_zone={time}&application={app}&format={format_j}"
        #t_url = f"https://api.tidesandcurrents.noaa.gov/api/prod/datagetter?date={date}&station={station}&product={product}&datum={datum}&units={unit}&time_zone={time}&application={app}&format={format_j}"
        t_resp = requests.get(t_url).json()
        velocity = t_resp["current_predictions"]["cp"][0]["Velocity_Major"] #In cm/second
        tide_ebb = t_resp["current_predictions"]["cp"][0]["meanEbbDir"] #degrees azimuth (360)
        tide_flood = t_resp["current_predictions"]["cp"][0]["meanFloodDir"] #degrees azimuth
        velo.append(velocity)
        ebb.append(tide_ebb)
        flood.append(tide_flood)
        s_result.append(t_station)
    except KeyError:
        print(t_station)
# Out:
# cc0201
# g10010
# gl0101
# gl0201
# lc0101
# lm0101
# lm0201
# mb0302
# mc0101
# mi0101
# mi0201
# sn0101
# sn0401
# sn0601
# t04010

# %%
velo
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-16-5480d3fca718> in <module>
# ----> 1 velo.value_counts()
#
# AttributeError: 'list' object has no attribute 'value_counts'

# %%
s_result
# Out:
# ['ca0101',
#  'cb0102',
#  'cb0201',
#  'cb0301',
#  'cb0402',
#  'cb0601',
#  'cb0701',
#  'cb0801',
#  'cb1001',
#  'cb1101',
#  'cb1201',
#  'cb1301',
#  'cc0301',
#  'cc0401',
#  'cp0101',
#  'db0301',
#  'db0502',
#  'g06010',
#  'g08010',
#  'g09010',
#  'hb0401',
#  'jx0302',
#  'jx0401',
#  'jx0501',
#  'jx0601',
#  'jx0701',
#  'kb0101',
#  'kb0201',
#  'kb0301',
#  'kb0401',
#  'lc0201',
#  'lc0301',
#  'mg0101',
#  'mg0201',
#  'n03020',
#  'n06010',
#  'n07010',
#  'nb0301',
#  'nl0101',
#  's06010',
#  's08010',
#  's09010',
#  's10010',
#  'sn0201',
#  'sn0301',
#  'sn0501',
#  'sn0701',
#  't01010',
#  't02010',
#  't03010']
